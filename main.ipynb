# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Loan.csv")

# %%
data.head()
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0         Master          22       13152            48       Married  ...
# 1      Associate          15       26045            48        Single  ...
# 2       Bachelor          26       17627            36       Married  ...
# 3    High School          34       37898            96        Single  ...
# 4      Associate          17        9184            36       Married  ...
#
#    MonthlyIncome UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# ...

# %% [markdown]
# EDA

# %% [markdown]
# Check for missing values

# %%
plt.figure(figsize=(30,6))
plt.subplot(1,3,1)
plt.title("Dataset Null")
sns.heatmap(data.isnull())
plt.show()

# %%
null_count = data.isnull().sum()
print(null_count)
# Out:
# ApplicationDate               0
# Age                           0
# AnnualIncome                  0
# CreditScore                   0
# EmploymentStatus              0
# EducationLevel                0
# Experience                    0
# LoanAmount                    0
# LoanDuration                  0
# MaritalStatus                 0
# NumberOfDependents            0
# HomeOwnershipStatus           0
# MonthlyDebtPayments           0
# CreditCardUtilizationRate     0
# NumberOfOpenCreditLines       0
# NumberOfCreditInquiries       0
# DebtToIncomeRatio             0
# BankruptcyHistory             0
# LoanPurpose                   0
# PreviousLoanDefaults          0
# PaymentHistory                0
# LengthOfCreditHistory         0
# SavingsAccountBalance         0
# CheckingAccountBalance        0
# TotalAssets                   0
# TotalLiabilities              0
# MonthlyIncome                 0
# UtilityBillsPaymentHistory    0
# JobTenure                     0
# ...

# %% [markdown]
# Check Column data types

# %%
print('data')
display(data.info())
# Out:
# data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ApplicationDate             20000 non-null  object
#  1   Age                         20000 non-null  int64
#  2   AnnualIncome                20000 non-null  int64
#  3   CreditScore                 20000 non-null  int64
#  4   EmploymentStatus            20000 non-null  object
#  5   EducationLevel              20000 non-null  object
#  6   Experience                  20000 non-null  int64
#  7   LoanAmount                  20000 non-null  int64
#  8   LoanDuration                20000 non-null  int64
#  9   MaritalStatus               20000 non-null  object
#  10  NumberOfDependents          20000 non-null  int64
#  11  HomeOwnershipStatus         20000 non-null  object
#  12  MonthlyDebtPayments         20000 non-null  int64
# ...

# %% [markdown]
# plotting the features

# %%
employment_count = data["EmploymentStatus"].value_counts()

#plotting the bar chart
plt.figure(figsize=(7,4))
sns.barplot(x=employment_count.index, y=employment_count.values)
plt.title("Employment status")
plt.xlabel("Employment Type")
plt.ylabel("Number of employees")
plt.xticks(rotation=90)
plt.show()

# %%
employment_count = data["EducationLevel"].value_counts()

#plotting the bar chart
plt.figure(figsize=(7,4))
sns.barplot(x=employment_count.index, y=employment_count.values)
plt.title("Education of employees")
plt.xlabel("Education Rank")
plt.ylabel("Number of employees")
plt.xticks(rotation=90)
plt.show()

# %%
employment_count = data["MaritalStatus"].value_counts()

#plotting the bar chart
plt.figure(figsize=(7,4))
sns.barplot(x=employment_count.index, y=employment_count.values)
plt.title("Marital status of employees")
plt.xlabel("Status")
plt.ylabel("Number of employees")
plt.xticks(rotation=90)
plt.show()

# %%
employment_count = data["NumberOfDependents"].value_counts()

#plotting the bar chart
plt.figure(figsize=(7,4))
sns.barplot(x=employment_count.index, y=employment_count.values)
plt.title("Dependendents of employees")
plt.xlabel("Number of dependents")
plt.ylabel("Number of employees")
plt.xticks(rotation=90)
plt.show()

# %%
employment_count = data["LoanPurpose"].value_counts()

#plotting the bar chart
plt.figure(figsize=(7,4))
sns.barplot(x=employment_count.index, y=employment_count.values)
plt.title("Dependendents of employees")
plt.xlabel("Number of dependents")
plt.ylabel("Number of employees")
plt.xticks(rotation=90)
plt.show()
